# %%
# dependencies
import duckdb
import pandas as pd

# connect to duckdb
con = duckdb.connect('../../sephora_products.duckdb')

# query from mart
df = con.sql("SELECT * FROM main.fact_product_metrics").df()

# get first 5 rows
df.head()

# close connection
con.close()
